# %% [markdown]
# # Pro Kabaddi League 2019 Dataset EDA

# %% [markdown]
# Questions
#
# 1. Relationship between height, weight & points?
# 2. Average points score by each team?
# 3. What is Disrtibution of points in matches?
# 4. How much players of different position in KPL?
# 5. Top players of league(Raiders, All-Rounders, Defenders)?
# 6. Analysis of my team & opponent team?

# %% [markdown]
# We will start the EDA for Pro Kabaddi League 2019 dataset. Starting from the basic analysis we will try to find some hidden insights from the data.

# %%
# Importing Libraries for Data Analysis

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the Fixture Results data file

fixture_result=pd.read_csv(r"D:\Jalpa Desai\Exploratory-Data-Analysis-main (1)\Pro-Kabbadi_Analysis\FixtureResults.csv")
fixture_result
# Out:
#      Unnamed: 0          Date               HomeTeam               AwayTeam  \
# 0             0  01.10. 01:00        Tamil Thalaivas                U Mumba
# 1             1  01.10. 00:00        Bengal Warriors           Dabang Delhi
# 2             2  30.09. 01:00       Haryana Steelers  Gujarat FortuneGiants
# 3             3  30.09. 00:00          Puneri Paltan           Dabang Delhi
# 4             4  29.09. 01:00  Gujarat FortuneGiants        Tamil Thalaivas
# ..          ...           ...                    ...                    ...
# 98           98  01.08. 00:00       Haryana Steelers   Jaipur Pink Panthers
# 99           99  30.07. 01:00        Bengal Warriors          Puneri Paltan
# 100         100  30.07. 00:00        Tamil Thalaivas          Patna Pirates
# 101         101  29.07. 01:00                U Mumba        Bengaluru Bulls
# 102         102  29.07. 00:00           Dabang Delhi       Haryana Steelers
#
#                     Result
# 0                  U Mumba
# ...

# %%
#Shape of Fixture Results data file

fixture_result.shape
# Out:
# (103, 5)

# %%
# Information about Null values & datatypes of Fixture Results Data File

fixture_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  103 non-null    int64
#  1   Date        103 non-null    object
#  2   HomeTeam    103 non-null    object
#  3   AwayTeam    103 non-null    object
#  4   Result      103 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.1+ KB

# %%
# Display the basic stats for the columns

fixture_result.describe()
# Out:
#        Unnamed: 0
# count  103.000000
# mean    51.000000
# std     29.877528
# min      0.000000
# 25%     25.500000
# 50%     51.000000
# 75%     76.500000
# max    102.000000

# %%
# Import the Upcoming Fixtures data file

upcoming_fixture=pd.read_csv(r"D:\Jalpa Desai\Exploratory-Data-Analysis-main (1)\Pro-Kabbadi_Analysis\Upcomingfixtures.csv")
upcoming_fixture
# Out:
#     Unnamed: 0          date               HomeTeam               AwayTeam
# 0            0  03.10. 00:00                U Mumba          Patna Pirates
# 1            1  03.10. 01:00       Haryana Steelers        Bengaluru Bulls
# 2            2  04.10. 00:00          Telugu Titans          Puneri Paltan
# 3            3  05.10. 00:00   Jaipur Pink Panthers        Bengaluru Bulls
# 4            4  05.10. 01:00       Haryana Steelers          Telugu Titans
# 5            5  06.10. 00:00              UP Yoddha           Dabang Delhi
# 6            6  06.10. 01:00  Gujarat FortuneGiants          Patna Pirates
# 7            7  07.10. 00:00        Bengal Warriors          Patna Pirates
# 8            8  07.10. 01:00              UP Yoddha          Puneri Paltan
# 9            9  08.10. 00:00          Telugu Titans  Gujarat FortuneGiants
# 10          10  08.10. 01:00        Tamil Thalaivas   Jaipur Pink Panthers
# ...

# %%
#Shape of Upcoming Fixture data file

upcoming_fixture.shape
# Out:
# (16, 4)

# %%
# Information about Null values & datatypes of Upcoming Fixture Data File

upcoming_fixture.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   date        16 non-null     object
#  2   HomeTeam    16 non-null     object
#  3   AwayTeam    16 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 640.0+ bytes

# %%
# Display the basic stats for the columns

upcoming_fixture.describe()
# Out:
#        Unnamed: 0
# count   16.000000
# mean     7.500000
# std      4.760952
# min      0.000000
# 25%      3.750000
# 50%      7.500000
# 75%     11.250000
# max     15.000000

# %%
# Import the League Table data file

league_table=pd.read_csv(r"D:\Jalpa Desai\Exploratory-Data-Analysis-main (1)\Pro-Kabbadi_Analysis\Leaguetable.csv")
league_table
# Out:
#     Unnamed: 0  Rank                   Team   P   W   L  T  Score Diff.  Pts
# 0            0     1      Dabang Delhi K.C.  20  15   3  2           83   82
# 1            1     2        Bengal Warriors  20  13   4  3           95   78
# 2            2     3       Haryana Steelers  19  12   6  1           24   65
# 3            3     4                U Mumba  19  10   8  1           37   59
# 4            4     5        Bengaluru Bulls  19  10   8  1           12   58
# 5            5     6            U.P. Yoddha  18  10   6  2          -19   58
# 6            6     7   Jaipur Pink Panthers  20   8  10  2          -18   52
# 7            7     8  Gujarat Fortunegiants  20   6  12  2           14   45
# 8            8     9          Puneri Paltan  20   6  11  3          -71   42
# 9            9    10          Patna Pirates  19   6  12  1           -1   40
# 10          10    11          Telugu Titans  18   5  10  3          -39   39
# ...

# %%
#Shape of League Table data file

league_table.shape
# Out:
# (12, 9)

# %%
# Information about Null values & datatypes of League Table Data File

league_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   12 non-null     int64
#  1   Rank         12 non-null     int64
#  2   Team         12 non-null     object
#  3   P            12 non-null     int64
#  4   W            12 non-null     int64
#  5   L            12 non-null     int64
#  6   T            12 non-null     int64
#  7   Score Diff.  12 non-null     int64
#  8   Pts          12 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 992.0+ bytes

# %%
# Display the basic stats for the columns

league_table.describe()
# Out:
#        Unnamed: 0       Rank          P          W          L          T  \
# count   12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean     5.500000   6.500000  19.333333   8.666667   8.666667   2.000000
# std      3.605551   3.605551   0.778499   3.601347   3.420083   0.852803
# min      0.000000   1.000000  18.000000   3.000000   3.000000   1.000000
# 25%      2.750000   3.750000  19.000000   6.000000   6.000000   1.000000
# 50%      5.500000   6.500000  19.500000   9.000000   9.000000   2.000000
# 75%      8.250000   9.250000  20.000000  10.500000  11.250000   3.000000
# max     11.000000  12.000000  20.000000  15.000000  14.000000   3.000000
#
#        Score Diff.        Pts
# count    12.000000  12.000000
# mean      0.000000  54.083333
# std      59.647449  15.715993
# min    -117.000000  31.000000
# 25%     -24.000000  41.500000
# 50%       5.500000  55.000000
# 75%      27.250000  60.500000
# max      95.000000  82.000000

# %%
# Import the Points Table data file

points_table=pd.read_csv(r"D:\Jalpa Desai\Exploratory-Data-Analysis-main (1)\Pro-Kabbadi_Analysis\Pointstable.csv")
points_table
# Out:
#      Unnamed: 0          Date               HomeTeam               AwayTeam  \
# 0             0  01.10. 01:00        Tamil Thalaivas                U Mumba
# 1             1  01.10. 00:00        Bengal Warriors           Dabang Delhi
# 2             2  30.09. 01:00       Haryana Steelers  Gujarat FortuneGiants
# 3             3  30.09. 00:00          Puneri Paltan           Dabang Delhi
# 4             4  29.09. 01:00  Gujarat FortuneGiants        Tamil Thalaivas
# ..          ...           ...                    ...                    ...
# 98           98  01.08. 00:00       Haryana Steelers   Jaipur Pink Panthers
# 99           99  30.07. 01:00        Bengal Warriors          Puneri Paltan
# 100         100  30.07. 00:00        Tamil Thalaivas          Patna Pirates
# 101         101  29.07. 01:00                U Mumba        Bengaluru Bulls
# 102         102  29.07. 00:00           Dabang Delhi       Haryana Steelers
#
# ...

# %%
#Shape of Points Table data file

points_table.shape
# Out:
# (103, 10)

# %%
# Information about Null values & datatypes of Points Table Data File

points_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Date                        103 non-null    object
#  2   HomeTeam                    103 non-null    object
#  3   AwayTeam                    103 non-null    object
#  4   Total_Points_HomeTeam       103 non-null    int64
#  5   Total_Points_AwayTeam       103 non-null    int64
#  6   FirstHalf_Points_HomeTeam   103 non-null    int64
#  7   FirstHalf_Points_AwayTeam   103 non-null    int64
#  8   SecondHalf_Points_HomeTeam  103 non-null    int64
#  9   SecondHalf_Points_AwayTeam  103 non-null    int64
# dtypes: int64(7), object(3)
# memory usage: 8.2+ KB

# %%
# Display the basic stats for the columns

points_table.describe()
# Out:
#        Unnamed: 0  Total_Points_HomeTeam  Total_Points_AwayTeam  \
# count  103.000000             103.000000             103.000000
# mean    51.000000              32.699029              33.184466
# std     29.877528               7.061127               7.917154
# min      0.000000              19.000000              20.000000
# 25%     25.500000              28.000000              27.000000
# 50%     51.000000              32.000000              33.000000
# 75%     76.500000              38.500000              38.500000
# max    102.000000              50.000000              60.000000
#
#        FirstHalf_Points_HomeTeam  FirstHalf_Points_AwayTeam  \
# count                 103.000000                 103.000000
# mean                   14.844660                  14.844660
# std                     4.304027                   4.096285
# min                     8.000000                   7.000000
# 25%                    11.000000                  12.000000
# ...

# %%
# Import the Team-Data data file

team_data=pd.read_csv(r"D:\Jalpa Desai\Exploratory-Data-Analysis-main (1)\Pro-Kabbadi_Analysis\TeamData.csv")
team_data
# Out:
#     Unnamed: 0                   Team  Games  TOTAL POINTS SCORED  \
# 0            0      Dabang Delhi K.C.     20                  742
# 1            1        Bengal Warriors     20                  718
# 2            2        Bengaluru Bulls     19                  656
# 3            3          Puneri Paltan     20                  652
# 4            4       Haryana Steelers     19                  650
# 5            5          Patna Pirates     19                  640
# 6            6   Jaipur Pink Panthers     20                  626
# 7            7  Gujarat Fortunegiants     20                  605
# 8            8                U Mumba     19                  598
# 9            9        Tamil Thalaivas     20                  578
# 10          10          Telugu Titans     18                  564
# 11          11            U.P. Yoddha     18                  551
#
#     TOTAL POINTS CONCEDED  AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  \
# ...

# %%
#Shape of Team-Data data file

team_data.shape
# Out:
# (12, 17)

# %%
# Information about Null values & datatypes of Team-Data Data File

team_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             12 non-null     int64
#  1   Team                   12 non-null     object
#  2   Games                  12 non-null     int64
#  3   TOTAL POINTS SCORED    12 non-null     int64
#  4   TOTAL POINTS CONCEDED  12 non-null     int64
#  5   AVG POINTS SCORED      12 non-null     float64
#  6   SUCCESSFUL RAIDS       12 non-null     int64
#  7   RAID POINTS            12 non-null     int64
#  8   AVG RAID POINTS        12 non-null     float64
#  9   SUCCESSFUL TACKLES     12 non-null     int64
#  10  TACKLE POINTS          12 non-null     int64
#  11  AVG TACKLE POINTS      12 non-null     float64
#  12  SUPER RAID             12 non-null     int64
#  13  SUPER TACKLES          12 non-null     int64
#  14  DO-OR-DIE RAID POINTS  12 non-null     int64
# ...

# %%
# Display the basic stats for the columns

team_data.describe()
# Out:
#        Unnamed: 0      Games  TOTAL POINTS SCORED  TOTAL POINTS CONCEDED  \
# count   12.000000  12.000000            12.000000              12.000000
# mean     5.500000  19.333333           631.666667             631.666667
# std      3.605551   0.778499            57.903263              47.549655
# min      0.000000  18.000000           551.000000             561.000000
# 25%      2.750000  19.000000           593.000000             600.000000
# 50%      5.500000  19.500000           633.000000             633.500000
# 75%      8.250000  20.000000           653.000000             647.750000
# max     11.000000  20.000000           742.000000             723.000000
#
#        AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  AVG RAID POINTS  \
# count          12.000000         12.000000    12.000000        12.000000
# mean           28.629167        286.333333   358.833333        18.550000
# std             1.956525         37.215181    43.848569         2.028192
# ...

# %%
# Import the Player-Data data file

player_data=pd.read_csv(r"C:\Users\Rupali\Downloads\archive (1)\PlayerData.csv")
player_data
# Out:
#      Unnamed: 0                      Name     Position          Born  \
# 0             0            Maninder Singh       Raider   Jan 1, 1990
# 1             1              K. Prapanjan       Raider  May 29, 1993
# 2             2            Mohammad Taghi       Raider  Oct 21, 1991
# 3             3             Rakesh Narwal       Raider   May 6, 1995
# 4             4           Ravindra Ramesh       Raider  Apr 16, 1996
# ..          ...                       ...          ...           ...
# 215         215              Arkam Shaikh  All Rounder   Nov 3, 1998
# 216         216                   Gurdeep  All Rounder  Jul 26, 1999
# 217         217  Mohsen Maghsoudloujafari  All Rounder  Mar 17, 1995
# 218         218                  Narender  All Rounder  Sep 10, 1986
# 219         219              Sachin Kumar  All Rounder   Aug 1, 1992
#
#                 Team      Height Nationality   Weight  Match Played  Points  \
# ...

# %%
#Shape of Player_Data data file

player_data.shape
# Out:
# (220, 30)

# %%
# Information about Null values & datatypes of Player_Data Data File

player_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    220 non-null    int64
#  1   Name                          220 non-null    object
#  2   Position                      220 non-null    object
#  3   Born                          220 non-null    object
#  4   Team                          220 non-null    object
#  5   Height                        220 non-null    object
#  6   Nationality                   220 non-null    object
#  7   Weight                        220 non-null    object
#  8   Match Played                  220 non-null    float64
#  9   Points                        220 non-null    float64
#  10  Career Best Points            220 non-null    float64
#  11  Not Out Percentage            220 non-null    float64
# ...

# %%
# Display the basic stats for the columns

player_data.describe()
# Out:
#        Unnamed: 0  Match Played      Points  Career Best Points  \
# count  220.000000    220.000000  220.000000          220.000000
# mean   109.500000      9.563636   30.195455            5.077273
# std     63.652704      7.126422   44.399936            5.138131
# min      0.000000      0.000000    0.000000            0.000000
# 25%     54.750000      2.000000    1.750000            1.000000
# 50%    109.500000      9.000000   11.500000            4.000000
# 75%    164.250000     17.000000   46.000000            7.000000
# max    219.000000     20.000000  258.000000           29.000000
#
#        Not Out Percentage       Raids  Successful Raids  Unsuccessful Raids  \
# count          220.000000  220.000000        220.000000          220.000000
# mean            48.598273   43.740909         15.186364           10.381818
# std             38.827724   81.437772         34.776085           18.944756
# min              0.000000    0.000000          0.000000            0.000000
# ...

# %%
# Merge both data files Team Data & Player Data

df1 = pd.merge(team_data,player_data, on = 'Team')
df1
# Out:
#      Unnamed: 0_x               Team  Games  TOTAL POINTS SCORED  \
# 0               0  Dabang Delhi K.C.     20                  742
# 1               0  Dabang Delhi K.C.     20                  742
# 2               0  Dabang Delhi K.C.     20                  742
# 3               0  Dabang Delhi K.C.     20                  742
# 4               0  Dabang Delhi K.C.     20                  742
# ..            ...                ...    ...                  ...
# 215            11        U.P. Yoddha     18                  551
# 216            11        U.P. Yoddha     18                  551
# 217            11        U.P. Yoddha     18                  551
# 218            11        U.P. Yoddha     18                  551
# 219            11        U.P. Yoddha     18                  551
#
#      TOTAL POINTS CONCEDED  AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  \
# 0                      659              31.20               361          437
# ...

# %%
# Merge both data files Team Data & Player Data

df2 = pd.merge(df1,league_table, on = 'Team')
df2
# Out:
#      Unnamed: 0_x               Team  Games  TOTAL POINTS SCORED  \
# 0               0  Dabang Delhi K.C.     20                  742
# 1               0  Dabang Delhi K.C.     20                  742
# 2               0  Dabang Delhi K.C.     20                  742
# 3               0  Dabang Delhi K.C.     20                  742
# 4               0  Dabang Delhi K.C.     20                  742
# ..            ...                ...    ...                  ...
# 215            11        U.P. Yoddha     18                  551
# 216            11        U.P. Yoddha     18                  551
# 217            11        U.P. Yoddha     18                  551
# 218            11        U.P. Yoddha     18                  551
# 219            11        U.P. Yoddha     18                  551
#
#      TOTAL POINTS CONCEDED  AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  \
# 0                      659              31.20               361          437
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220 entries, 0 to 219
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0_x                  220 non-null    int64
#  1   Team                          220 non-null    object
#  2   Games                         220 non-null    int64
#  3   TOTAL POINTS SCORED           220 non-null    int64
#  4   TOTAL POINTS CONCEDED         220 non-null    int64
#  5   AVG POINTS SCORED             220 non-null    float64
#  6   SUCCESSFUL RAIDS              220 non-null    int64
#  7   RAID POINTS                   220 non-null    int64
#  8   AVG RAID POINTS               220 non-null    float64
#  9   SUCCESSFUL TACKLES            220 non-null    int64
#  10  TACKLE POINTS                 220 non-null    int64
#  11  AVG TACKLE POINTS             220 non-null    float64
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0_x', 'Team', 'Games', 'TOTAL POINTS SCORED',
#        'TOTAL POINTS CONCEDED', 'AVG POINTS SCORED', 'SUCCESSFUL RAIDS',
#        'RAID POINTS', 'AVG RAID POINTS', 'SUCCESSFUL TACKLES', 'TACKLE POINTS',
#        'AVG TACKLE POINTS', 'SUPER RAID', 'SUPER TACKLES',
#        'DO-OR-DIE RAID POINTS', 'ALL-OUTS INFLICTED', 'ALL-OUTS CONCEDED',
#        'Unnamed: 0_y', 'Name', 'Position', 'Born', 'Height', 'Nationality',
#        'Weight', 'Match Played', 'Points', 'Career Best Points',
#        'Not Out Percentage', 'Raids', 'Successful Raids', 'Unsuccessful Raids',
#        'Empty Raid', 'Successful Raid Percentage', 'Raid Touch Points',
#        'Raid Bonus Points', 'Total Raid Points', 'Super Raids', 'Super 10s',
#        'Tackles', 'Successful Tackles', 'Unsuccessful Tackles',
#        'Successful Tackles Per Match', 'Tackle Bonus Points',
#        'Tackle Success Rate', 'Super Tackles', 'High 5s', 'Unnamed: 0', 'Rank',
# ...

# %%
# Merge both data files Team Data & Player Data

df3 = pd.merge(points_table,fixture_result, on = 'HomeTeam')
df3
# Out:
#      Unnamed: 0_x        Date_x         HomeTeam        AwayTeam_x  \
# 0               0  01.10. 01:00  Tamil Thalaivas           U Mumba
# 1               0  01.10. 01:00  Tamil Thalaivas           U Mumba
# 2               0  01.10. 01:00  Tamil Thalaivas           U Mumba
# 3               0  01.10. 01:00  Tamil Thalaivas           U Mumba
# 4               0  01.10. 01:00  Tamil Thalaivas           U Mumba
# ..            ...           ...              ...               ...
# 936            80  12.08. 00:00  Bengaluru Bulls  Haryana Steelers
# 937            80  12.08. 00:00  Bengaluru Bulls  Haryana Steelers
# 938            80  12.08. 00:00  Bengaluru Bulls  Haryana Steelers
# 939            80  12.08. 00:00  Bengaluru Bulls  Haryana Steelers
# 940            80  12.08. 00:00  Bengaluru Bulls  Haryana Steelers
#
#      Total_Points_HomeTeam  Total_Points_AwayTeam  FirstHalf_Points_HomeTeam  \
# 0                       32                     36                         11
# ...

# %% [markdown]
# Q : Relationship between height, weight & points ?

# %%
player_data[['Name','Height','Weight','Points']]
# Out:
#                          Name      Height   Weight  Points
# 0              Maninder Singh        6 ft    76 kg   205.0
# 1                K. Prapanjan   6 ft 1 in  83.6 kg   101.0
# 2              Mohammad Taghi           -        -     1.0
# 3               Rakesh Narwal   6 ft 1 in    82 kg     6.0
# 4             Ravindra Ramesh           -        -     2.0
# ..                        ...         ...      ...     ...
# 215              Arkam Shaikh  5 ft 10 in    79 kg     0.0
# 216                   Gurdeep  5 ft 11 in        -     2.0
# 217  Mohsen Maghsoudloujafari  5 ft 10 in    78 kg     8.0
# 218                  Narender   5 ft 8 in    78 kg     0.0
# 219              Sachin Kumar   5 ft 7 in        -     4.0
#
# [220 rows x 4 columns]

# %%
# Remove the Special Character in perticular Columns in dataset

df2['Height']=df2['Height'].str.replace('ft','.')
df2['Height']=df2['Height'].str.replace('in',' ')
df2['Weight']=df2['Weight'].str.replace('kg',' ')

# %%
# Display columns after removing the characters

df2[['Name','Height','Weight','Points']]
# Out:
#                          Name    Height Weight  Points
# 0              Joginder Singh   5 . 9     75      46.0
# 1                 Aman Kadian         -      -     4.0
# 2             Chandran Ranjit  5 . 10     68     110.0
# 3                Naveen Kumar  5 . 10     76     258.0
# 4               Neeraj Narwal  5 . 11     70       0.0
# ..                        ...       ...    ...     ...
# 215              Arkam Shaikh  5 . 10     79       0.0
# 216                   Gurdeep  5 . 11        -     2.0
# 217  Mohsen Maghsoudloujafari  5 . 10     78       8.0
# 218                  Narender   5 . 8     78       0.0
# 219              Sachin Kumar   5 . 7        -     4.0
#
# [220 rows x 4 columns]

# %%
# Top 10 Player Name with their Points

points_df =df1.Team.sort_values(ascending=False).head(10)
df1.loc[df1['Team'].isin(points_df)][['Name','Points']]
df1.loc[df1['Team'].isin(points_df)][['Name','Points']].plot.bar(x='Name',y="Points",
                                                                    figsize = (10,6),color="teal")
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
# Co-relation table

team_corr = player_data[['Height','Weight','Points']].corr()
team_corr
# Out:
#         Points
# Points     1.0

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(team_corr, 
            xticklabels=team_corr.columns.values,
            yticklabels=team_corr.columns.values,annot= True)
plt.show()

# %%
#Checking the Team Co-relation table

team_correlation = df2[['TOTAL POINTS SCORED',
       'TOTAL POINTS CONCEDED', 'AVG POINTS SCORED', 'SUCCESSFUL RAIDS',
       'RAID POINTS', 'AVG RAID POINTS', 'SUCCESSFUL TACKLES', 'TACKLE POINTS',
       'AVG TACKLE POINTS', 'SUPER RAID', 'SUPER TACKLES',
       'DO-OR-DIE RAID POINTS', 'ALL-OUTS INFLICTED', 'ALL-OUTS CONCEDED',]].corr()
team_correlation
# Out:
#                        TOTAL POINTS SCORED  TOTAL POINTS CONCEDED  \
# TOTAL POINTS SCORED               1.000000               0.370620
# TOTAL POINTS CONCEDED             0.370620               1.000000
# AVG POINTS SCORED                 0.831190               0.307208
# SUCCESSFUL RAIDS                  0.924794               0.421786
# RAID POINTS                       0.939342               0.414694
# AVG RAID POINTS                   0.837393               0.262502
# SUCCESSFUL TACKLES                0.371374               0.348889
# TACKLE POINTS                     0.181304               0.358152
# AVG TACKLE POINTS                -0.104209               0.080130
# SUPER RAID                        0.534493              -0.082302
# SUPER TACKLES                    -0.273313               0.153768
# DO-OR-DIE RAID POINTS            -0.251902              -0.207538
# ALL-OUTS INFLICTED                0.777687              -0.169233
# ...

# %%
f, ax = plt.subplots(figsize=(14, 9))
sns.heatmap(team_correlation, 
            xticklabels=team_correlation.columns.values,
            yticklabels=team_correlation.columns.values,annot= True)
plt.show()

# %% [markdown]
# Q : Average points scored by each team ?

# %%
team_data[['Team','AVG POINTS SCORED']]
# Out:
#                      Team  AVG POINTS SCORED
# 0       Dabang Delhi K.C.              31.20
# 1         Bengal Warriors              30.90
# 2         Bengaluru Bulls              30.73
# 3           Puneri Paltan              29.50
# 4        Haryana Steelers              30.10
# 5           Patna Pirates              29.42
# 6    Jaipur Pink Panthers              27.80
# 7   Gujarat Fortunegiants              26.15
# 8                 U Mumba              26.73
# 9         Tamil Thalaivas              25.75
# 10          Telugu Titans              28.55
# 11            U.P. Yoddha              26.72

# %%
plt.figure(figsize=(12,8))

sns.barplot(y="Team",x="AVG POINTS SCORED",data=df1)
# Out:
# <AxesSubplot:xlabel='AVG POINTS SCORED', ylabel='Team'>

# %% [markdown]
# Q : What is distribution of points in matches ?

# %%
league_table
# Out:
#     Unnamed: 0  Rank                   Team   P   W   L  T  Score Diff.  Pts
# 0            0     1      Dabang Delhi K.C.  20  15   3  2           83   82
# 1            1     2        Bengal Warriors  20  13   4  3           95   78
# 2            2     3       Haryana Steelers  19  12   6  1           24   65
# 3            3     4                U Mumba  19  10   8  1           37   59
# 4            4     5        Bengaluru Bulls  19  10   8  1           12   58
# 5            5     6            U.P. Yoddha  18  10   6  2          -19   58
# 6            6     7   Jaipur Pink Panthers  20   8  10  2          -18   52
# 7            7     8  Gujarat Fortunegiants  20   6  12  2           14   45
# 8            8     9          Puneri Paltan  20   6  11  3          -71   42
# 9            9    10          Patna Pirates  19   6  12  1           -1   40
# 10          10    11          Telugu Titans  18   5  10  3          -39   39
# ...

# %%
fig, axx =plt.subplots(figsize=(16,8))
sns.barplot(x='W', y='Team', data=league_table, palette="Set1")
axx.set_title("Analysis of Winning Match by Team")

#sns.barplot(y="Team",x="W",data=league_table)
# Out:
# Text(0.5, 1.0, 'Analysis of Winning Match by Team')

# %%
fig, axx =plt.subplots(figsize=(16,8))
sns.barplot(x='L', y='Team', data=league_table, palette="Set1")
axx.set_title("Analysis of Losing Match by Team")
# Out:
# Text(0.5, 1.0, 'Analysis of Losing Match by Team')

# %%
fig, axx =plt.subplots(figsize=(16,8))
sns.barplot(x='T', y='Team', data=league_table, palette="Set1")
axx.set_title("Analysis of Tie Match")
# Out:
# Text(0.5, 1.0, 'Analysis of Tie Match')

# %%
fig, axx =plt.subplots(figsize=(16,8))
sns.barplot(x='Score Diff.', y='Pts',hue='Team', data=league_table, palette="Set1")
axx.set_title("Analysis Score Difference &  points")
# Out:
# Text(0.5, 1.0, 'Analysis Score Difference &  points')

# %%
fig, axx =plt.subplots(figsize=(16,8))
sns.barplot(x='W',y='L', hue='Team', data=league_table, palette="Set1")
axx.set_title("Analysis of total Matches")
# Out:
# Text(0.5, 1.0, 'Analysis of total Matches')

# %%
tables=league_table[['W','L','T','Score Diff.','Pts']]
tables.hist(figsize=(20,10),color="darkslateblue",alpha=0.8)
# Out:
# array([[<AxesSubplot:title={'center':'W'}>,
#         <AxesSubplot:title={'center':'L'}>],
#        [<AxesSubplot:title={'center':'T'}>,
#         <AxesSubplot:title={'center':'Score Diff.'}>],
#        [<AxesSubplot:title={'center':'Pts'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Q : How much Players of different position in PKL ?

# %%
player_data[['Name','Position']]
# Out:
#                          Name     Position
# 0              Maninder Singh       Raider
# 1                K. Prapanjan       Raider
# 2              Mohammad Taghi       Raider
# 3               Rakesh Narwal       Raider
# 4             Ravindra Ramesh       Raider
# ..                        ...          ...
# 215              Arkam Shaikh  All Rounder
# 216                   Gurdeep  All Rounder
# 217  Mohsen Maghsoudloujafari  All Rounder
# 218                  Narender  All Rounder
# 219              Sachin Kumar  All Rounder
#
# [220 rows x 2 columns]

# %%
# Find total number of Player by Position

total_player = player_data.groupby(['Position'], as_index=False).count()[['Name','Position']]
total_player.columns=['Total Players','Position']


total_player
# Out:
#    Total Players                         Position
# 0             44                      All Rounder
# 1             14                         Defender
# 2             16            Defender, left corner
# 3             17             Defender, left cover
# 4              1  Defender, right and left corner
# 5              1   Defender, right and left cover
# 6             20           Defender, right corner
# 7             17            Defender, right cover
# 8             90                           Raider

# %%
# Plot for Total Players by their Position in PKL

fig, axx =plt.subplots(figsize=(12,6))
axx.set_title("Total Players by their Position in PKL")
sns.barplot(x='Total Players', y='Position',hue='Position', data=total_player, palette='Set1')
# Out:
# <AxesSubplot:title={'center':'Total Players by their Position in PKL'}, xlabel='Total Players', ylabel='Position'>

# %% [markdown]
# Q : Top Players of League ?

# %%
# Position of the Players

pos=['All Rounder','Raider','Defender']
pos_play = player_data.loc[player_data['Position'].isin(pos)]
pos_play

# Find total number of Position

total_pos = pos_play.groupby(['Position'], as_index=False).count()[['Position','Name']]
total_pos.columns=['Position','Total Players']

# Find total position count of each type

top5pos = pos_play.groupby(['Position','Name'], as_index=False)[['Position']].count()
top5pos.columns=['Name', 'Position']

top5pos
# Out:
#                  Name  Position
# 0     Ajinkya Rohidas         1
# 1        Amir Santosh         1
# 2          Amit Kumar         2
# 3        Arkam Shaikh         1
# 4              Armaan         1
# ..                ...       ...
# 139             Vinay         1
# 140     Vineet Sharma         1
# 141       Vinod Kumar         1
# 142      Vinoth Kumar         1
# 143  Yashwant Bishnoi         1
#
# [144 rows x 2 columns]

# %%
player_data['Position'].value_counts().sort_values(ascending=False).head(5)
player_data['Position'].value_counts().sort_values(ascending=False).head(5).plot(kind='pie',figsize=(10,6), 
title="Position of Players", autopct='%1.2f%%')
plt.axis('equal')
# Out:
# (-1.1253132907477046,
#  1.1012053947975098,
#  -1.1071976815586522,
#  1.115746588131646)

# %%
player_data['Name'].value_counts().sort_values(ascending=False).head(5)
player_data['Name'].value_counts().sort_values(ascending=False).head(5).plot(kind='pie',figsize=(10,6), 
title="Top 5 Players", autopct='%1.2f%%')
plt.axis('equal')
# Out:
# (-1.1000000188987558,
#  1.1000000353324482,
#  -1.1000000262939185,
#  1.1000000098602216)

# %% [markdown]
# Q : Analysis of my Team and opponent Team

# %%
df2.head(2)
# Out:
#    Unnamed: 0_x               Team  Games  TOTAL POINTS SCORED  \
# 0             0  Dabang Delhi K.C.     20                  742
# 1             0  Dabang Delhi K.C.     20                  742
#
#    TOTAL POINTS CONCEDED  AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  \
# 0                    659               31.2               361          437
# 1                    659               31.2               361          437
#
#    AVG RAID POINTS  SUCCESSFUL TACKLES  ...  Super Tackles  High 5s  \
# 0            21.85                 181  ...            4.0      1.0
# 1            21.85                 181  ...            0.0      0.0
#
#    Unnamed: 0  Rank   P   W  L  T Score Diff. Pts
# 0           0     1  20  15  3  2          83  82
# 1           0     1  20  15  3  2          83  82
#
# [2 rows x 54 columns]

# %%
df2.columns
# Out:
# Index(['Unnamed: 0_x', 'Team', 'Games', 'TOTAL POINTS SCORED',
#        'TOTAL POINTS CONCEDED', 'AVG POINTS SCORED', 'SUCCESSFUL RAIDS',
#        'RAID POINTS', 'AVG RAID POINTS', 'SUCCESSFUL TACKLES', 'TACKLE POINTS',
#        'AVG TACKLE POINTS', 'SUPER RAID', 'SUPER TACKLES',
#        'DO-OR-DIE RAID POINTS', 'ALL-OUTS INFLICTED', 'ALL-OUTS CONCEDED',
#        'Unnamed: 0_y', 'Name', 'Position', 'Born', 'Height', 'Nationality',
#        'Weight', 'Match Played', 'Points', 'Career Best Points',
#        'Not Out Percentage', 'Raids', 'Successful Raids', 'Unsuccessful Raids',
#        'Empty Raid', 'Successful Raid Percentage', 'Raid Touch Points',
#        'Raid Bonus Points', 'Total Raid Points', 'Super Raids', 'Super 10s',
#        'Tackles', 'Successful Tackles', 'Unsuccessful Tackles',
#        'Successful Tackles Per Match', 'Tackle Bonus Points',
#        'Tackle Success Rate', 'Super Tackles', 'High 5s', 'Unnamed: 0', 'Rank',
# ...

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['TOTAL POINTS SCORED'].values)
a.set_ylabel('Teams Total Points Scored')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['TOTAL POINTS CONCEDED'].values)
a.set_ylabel('Teams Total Points Conceded')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['AVG POINTS SCORED'].values)
a.set_ylabel('Teams Avg Points Scored')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['SUCCESSFUL RAIDS'].values)
a.set_ylabel('Teams Succesful Raids')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['RAID POINTS'].values)
a.set_ylabel('Teams Raid Points')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['AVG RAID POINTS'].values)
a.set_ylabel('Teams Avg Raid Points')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['SUPER RAID'].values)
a.set_ylabel('Teams Super Raid')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['SUCCESSFUL TACKLES'].values)
a.set_ylabel('SUCCESSFUL TACKLES')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['TACKLE POINTS'].values)
a.set_ylabel('TACKLE POINTS')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['AVG TACKLE POINTS'].values)
a.set_ylabel('AVG TACKLE POINTS')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['SUPER TACKLES'].values)
a.set_ylabel('SUPER TACKLES')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['DO-OR-DIE RAID POINTS'].values)
a.set_ylabel('DO-OR-DIE RAID POINTS')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['ALL-OUTS INFLICTED'].values)
a.set_ylabel('ALL-OUTS INFLICTED')
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.subplot(2, 2, 1)
a=sns.barplot(x=df2['Team'].values, y=df2['ALL-OUTS CONCEDED'].values)
a.set_ylabel('ALL-OUTS CONCEDED')
plt.show()
